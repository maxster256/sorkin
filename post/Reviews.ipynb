# %%
import pandas as pd

# %%
df = pd.read_pickle("rated_reviews.gzip")

# %%
df = df.drop(["_id"], axis=1)
df.head(5)
# Out:
#                  title                author                        movie  \
# 0    W domach z betonu           Anna Bielak                Melasa (2012)
# 1  Dramat bez bohatera  Bartosz Staszczyszyn            Mój biegun (2013)
# 2         Zemsta hitów      Jakub Popielecki  Avengers: Koniec gry (2019)
# 3        Waga piórkowa     Michał Walkiewicz              Underdog (2019)
# 4       Złap króliczka      Dorota Kostrzewa            Miss marca (2009)
#
#   rating              date                                             review  \
# 0      3  12/11/2014 15:12  "Melasa" Carlosa Lechugi jest porównywana do "...
# 1      2  24/10/2013 00:00  W "Moim biegunie" mnóstwo jest ładnych obrazkó...
# 2      7  24/04/2019 00:30  Siedem lat po premierze pierwszych "Avengers" ...
# 3      5  14/01/2019 15:03  Jesteśmy w obskurnej hotelowej toalecie, gdzie...
# 4      5  15/07/2009 00:00  Kto ma większego pecha od chłopaka, który za k...
#
#   helpful
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df.describe()
# Out:
#                        title           author                  movie rating  \
# count                  11027             9738                  11027  11027
# unique                 10696             1463                   6297     10
# top     Zmarnowany potencjał  Marcin Pietrzyk  Mroczny Rycerz (2008)      7
# freq                       7             1090                     27   2265
#
#                     date review helpful
# count              11027  11027    7007
# unique              6093  10995      99
# top     02/01/2008 00:00            50%
# freq                  38     33     285

# %%
df = df.astype({'rating': 'int32'})
df.dtypes
# Out:
# title      object
# author     object
# movie      object
# rating      int32
# date       object
# review     object
# helpful    object
# dtype: object

# %%
def add_sentiment():
    """
    Adds a sentiment class to the dataset based on the rating given by the reviewer.
    """
    def determine_sentiment(row):
        if row['rating'] in [1, 2, 3]:
            return "negative"
        elif row['rating'] in [4, 5, 6]:
            return "neutral"
        elif row['rating'] in [7, 8, 9, 10]:
            return "positive"
            
    df['sentiment'] = df.apply(lambda row: determine_sentiment(row), axis=1)

# %%
add_sentiment()

# %%
df.head(15)
# Out:
#                          title                author  \
# 0            W domach z betonu           Anna Bielak
# 1          Dramat bez bohatera  Bartosz Staszczyszyn
# 2                 Zemsta hitów      Jakub Popielecki
# 3                Waga piórkowa     Michał Walkiewicz
# 4               Złap króliczka      Dorota Kostrzewa
# 5             Prawo Murphy'ego     Michał Walkiewicz
# 6   Striptiz na przedmieściach      Jakub Popielecki
# 7               Camera obscura       Marcin Pietrzyk
# 8       Melancholia cukiernika     Marcin Stachowicz
# 9      Kabaret starszych panów      Łukasz Muszyński
# 10  Dyskretny urok prostytucji     Michał Walkiewicz
# 11          Życie to nie bajka      Dorota Kostrzewa
# 12           Precz z maczyzmem             Adam Kruk
# 13         Wojownicy Spandeksu      Marcin Dąbkowski
# 14                Grać czy być       Marcin Pietrzyk
#
#                                    movie  rating              date  \
# 0                          Melasa (2012)       3  12/11/2014 15:12
# 1                      Mój biegun (2013)       2  24/10/2013 00:00
# 2            Avengers: Koniec gry (2019)       7  24/04/2019 00:30
# 3                        Underdog (2019)       5  14/01/2019 15:03
# 4                      Miss marca (2009)       5  15/07/2009 00:00
# 5                            Love (2015)       5  22/05/2015 13:17
# 6           Popołudniowa igraszka (2013)       7  25/10/2013 00:00
# 7                            Świt (2015)      10  01/04/2017 10:46
# 8   Kwiat wiśni i czerwona fasola (2015)       7  04/08/2016 12:43
# 9                  Niezniszczalni (2010)       5  19/08/2010 00:00
# 10                     Sponsoring (2011)       7  06/02/2012 00:00
# 11                     Telenowela (2006)       6  31/03/2009 00:00
# 12              La tercera orilla (2014)       7  14/02/2014 00:00
# 13                  Power Rangers (2017)       6  24/03/2017 12:08
# 14                    Jesteś tam? (2010)       6  10/10/2010 00:00
#
#                                                review helpful sentiment
# 0   "Melasa" Carlosa Lechugi jest porównywana do "...     NaN  negative
# 1   W "Moim biegunie" mnóstwo jest ładnych obrazkó...     NaN  negative
# 2   Siedem lat po premierze pierwszych "Avengers" ...     NaN  positive
# 3   Jesteśmy w obskurnej hotelowej toalecie, gdzie...     NaN   neutral
# 4   Kto ma większego pecha od chłopaka, który za k...     NaN   neutral
# 5   Zaczyna się obrazem leżącej na łóżku i wzajemn...     NaN   neutral
# 6   Reżyserka-debiutantka Jill Soloway już w pierw...     NaN  positive
# 7   Wejście "Świtu" do kin to powód do świętowania...     NaN  positive
# 8   An – bo taki jest oryginalny tytuł filmu Naomi...     NaN  positive
# 9   Sylvester Stallone ma 64 lata na karku, ale me...     NaN   neutral
# 10  Człowiek miewa natręctwa, reżyser – obsesje. P...     NaN  positive
# 11  Przewrotnie "Telenowela" w reżyserii debiutują...     NaN   neutral
# 12  Nastoletni Nicolás nie mówi za wiele. Zajmuje ...     NaN  positive
# 13  Końcówka lat 90. Kilkuletni ja, przebrany w ob...     NaN   neutral
# 14  Holender David Verbeek w filmie "Jesteś tam?" ...     NaN   neutral

# %%
df.set_index("movie", inplace=True)

# %%
df.loc["Zodiak (2007)"]
# Out:
#                                                       title           author  \
# movie
# Zodiak (2007)                          Zbrodnicza układanka  Marcin Pietrzyk
# Zodiak (2007)               Niewiarygodnie klimatyczny film      Midgardsorm
# Zodiak (2007)  Konfrontacja z gatunkowymi przyzwyczajeniami         eon_blue
#
#                rating              date  \
# movie
# Zodiak (2007)       7  13/06/2007 00:00
# Zodiak (2007)       9  26/11/2010 00:00
# Zodiak (2007)       9  28/06/2007 00:00
#
#                                                           review helpful  \
# movie
# Zodiak (2007)  Jest 1 sierpnia 1969 roku. Do redakcji trzech ...     NaN
# Zodiak (2007)  Tak - "Siedem" ma mroczny i ponury klimat. Ale...     82%
# Zodiak (2007)  Nazwisko Davida Finchera, pomimo mocnej pozycj...     49%
#
#               sentiment
# movie
# Zodiak (2007)  positive
# Zodiak (2007)  positive
# Zodiak (2007)  positive

# %%
df.loc[df["sentiment"].isna()]
